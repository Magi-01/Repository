# %%
class A:
    def g(self, x ) :
        self.f(x + 1)

    def f (self , x ) :
        print(f"A {x}")

class B(A):
    def g (self, x ) :
        self.f( x + 2)

class C(B) :
    def f (self, x) :
        print (f"C {x}")

class D(C) :
    def g (self, x) :
        super ( ) . g ( x + 1)
        
x = D( )
x . g ( 1 )
# Out:
# C 4

# %%
def f(g, x):
    def h1(y):
        return x + 2*y
    def h2(z):
        return g(h1(x))
    return h2

func = f ( lambda x : x + 2 , 6)
func(3)
# Out:
# 20
