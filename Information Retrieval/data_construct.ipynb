# %%
import requests
import pandas as pd
from time import sleep

BASE_URL = "https://api.openalex.org/works"
# Look-up Terms
Query = ["artificial intelligence", "neural networks", "supervised learning", "Unsupervised learning", "AI privacy"]

# %%
def fetch_papers(query, per_page=20, pages=5):
    print(query)
    papers = []
    for page in range(1, pages+1):
        # Fetch the papers
        try:
            url = f"{BASE_URL}?filter=title.search:{query},open_access.is_oa:true&per-page={per_page}&page={page}"
            r = requests.get(url)
            data = r.json()
            results = data.get("results", [])
            if not results:
                print(f"No results found for page {page}")
                break
            # Store them 
            for d in results:
                papers.append({
                    "id": d.get("id"),
                    "title": d.get("title"),
                    "abstract": d.get("abstract_inverted_index"),
                    "year": d.get("publication_year"),
                    "concepts": [c["display_name"] for c in d.get("concepts", [])]
                })
        except requests.exceptions.RequestException as e:
            print("Attempt failed:", e)
            sleep(2)
    return papers

# %%
all_papers = []

for q in Query:
    papers = fetch_papers(q, per_page=10, pages=20)  # returns list of dicts
    all_papers.extend(papers)  # append to the master list

# Convert to DataFrame once at the end
df = pd.DataFrame(all_papers)
print(df.head())
# Out:
# artificial intelligence
# neural networks
# supervised learning
# Unsupervised learning
# AI privacy
#                                  id  \
# 0  https://openalex.org/W2122410182
# 1  https://openalex.org/W2981731882
# 2  https://openalex.org/W2803760365
# 3  https://openalex.org/W2664267452
# 4  https://openalex.org/W2953532875
#
#                                                title  \
# 0         Artificial intelligence: a modern approach
# 1  Explainable Artificial Intelligence (XAI): Con...
# 2               Artificial intelligence in radiology
# 3  Artificial intelligence in healthcare: past, p...
# 4  The potential for artificial intelligence in h...
#
#                                             abstract  year  \
# 0  {'The': [0], 'long-anticipated': [1], 'revisio...  1995
# 1                                               None  2019
# 2                                               None  2018
# 3  {'Artificial': [0], 'intelligence': [1], '(AI)...  2017
# 4                                               None  2019
#
#                                             concepts
# 0  [Artificial intelligence, Computer science, In...
# 1  [Computer science, Artificial intelligence, Ta...
# 2  [Pace, Computer science, Convolutional neural ...
# 3  [Cognitive computing, Health care, Data scienc...
# 4  [Health care, Key (lock), Field (mathematics),...

# %%
# Clean dataframe
df = df[df['abstract'].notna()]

# %%
df.size
# Out:
# 3970

# %%
def reconstruct_abstract(inverted_index):
    if not inverted_index:
        return ""
    
    # position_map[pos] = word
    position_map = {}
    for word, positions in inverted_index.items():
        for pos in positions:
            position_map[pos] = word
    
    # Sort positions and join words
    words = [position_map[pos] for pos in sorted(position_map.keys())]
    return " ".join(words)

# %%
df["abstract_text"] = df["abstract"].apply(reconstruct_abstract)

# %%
df
# Out:
#                                    id  \
# 0    https://openalex.org/W2122410182
# 3    https://openalex.org/W2664267452
# 5    https://openalex.org/W2891503716
# 6    https://openalex.org/W3017131514
# 8    https://openalex.org/W1543659671
# ..                                ...
# 993  https://openalex.org/W4399695555
# 994  https://openalex.org/W4400022865
# 996  https://openalex.org/W4383197555
# 997  https://openalex.org/W4393067727
# 999  https://openalex.org/W4393971166
#
#                                                  title  \
# 0           Artificial intelligence: a modern approach
# 3    Artificial intelligence in healthcare: past, p...
# 5    Peeking Inside the Black-Box: A Survey on Expl...
# 6       Artificial Intelligence in Education: A Review
# 8    Artificial Intelligence: A Guide to Intelligen...
# ..                                                 ...
# 993  Evaluating Privacy, Security, and Trust Percep...
# 994  Privacy Implications of Explainable AI in Data...
# 996  Translating theory into practice: assessing th...
# 997  Examining Privacy and Trust Issues at the Edge...
# 999  Perceived Trustworthiness of Human vs. AI Inst...
#
#                                               abstract  year  \
# 0    {'The': [0], 'long-anticipated': [1], 'revisio...  1995
# 3    {'Artificial': [0], 'intelligence': [1], '(AI)...  2017
# 5    {'At': [0], 'the': [1, 4, 28, 45, 57, 101, 130...  2018
# 6    {'The': [0, 110], 'purpose': [1], 'of': [2, 10...  2020
# 8    {'From': [0], 'the': [1, 4, 12, 60, 76, 87, 95...  2001
# ..                                                 ...   ...
# 993  {'Conversational': [0], 'AI': [1], '(CAI)': [2...  2024
# 994  {'Machine': [0], 'learning': [1, 171], '(ML)':...  2024
# 996  {'Artificial': [0], 'Intelligence': [1], '(AI)...  2023
# 997  {'The': [0, 126, 141], 'growing': [1], 'domain...  2023
# 999  {'Recent': [0], 'work': [1], 'highlights': [2]...  2024
#
#                                               concepts  \
# 0    [Artificial intelligence, Computer science, In...
# 3    [Cognitive computing, Health care, Data scienc...
# 5    [Transparency (behavior), Sine qua non, Comput...
# 6    [Computer science, Adaptability, Personalized ...
# 8    [Computer science, Jargon, Expert system, Inte...
# ..                                                 ...
# 993  [Internet privacy, Perception, Computer securi...
# 994  [Internet privacy, Computer science, Informati...
# 996  [Computer science, Context (archaeology), Adve...
# 997  [Computer science, Profiling (computer program...
# 999  [Distrust, Digital literacy, Trustworthiness, ...
#
#                                          abstract_text
# 0    The long-anticipated revision of this #1 selli...
# 3    Artificial intelligence (AI) aims to mimic hum...
# 5    At the dawn of the fourth industrial revolutio...
# 6    The purpose of this study was to assess the im...
# 8    From the Publisher:\r\nVirtually all the liter...
# ..                                                 ...
# 993  Conversational AI (CAI) systems which encompas...
# 994  Machine learning (ML) models, demonstrably pow...
# 996  Artificial Intelligence (AI) has achieved rema...
# 997  The growing domain of liquidity in computing e...
# 999  Recent work highlights digital privacy educati...
#
# [794 rows x 6 columns]

# %%
df.to_csv("openalex_papers4.csv", index=False)
